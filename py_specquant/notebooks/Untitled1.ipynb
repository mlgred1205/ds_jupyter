# %%
#READ FILE IN

df <- read.csv("../data//test_scounts.csv")

# %%
df
# Out:
#     Description
# 1   sp|P35580|MYH10_HUMAN Myosin-10 OS=Homo sapiens GN=MYH10 PE=1 SV=3
# 2   sp|P35579|MYH9_HUMAN Myosin-9 OS=Homo sapiens GN=MYH9 PE=1 SV=4
# 3   sp|P08670|VIME_HUMAN Vimentin OS=Homo sapiens GN=VIM PE=1 SV=4
# 4   sp|O43707|ACTN4_HUMAN Alpha-actinin-4 OS=Homo sapiens GN=ACTN4 PE=1 SV=2
# 5   sp|P63261|ACTG_HUMAN Actin; cytoplasmic 2 OS=Homo sapiens GN=ACTG1 PE=1 SV=1
# 6   sp|Q13813|SPTN1_HUMAN Spectrin alpha chain; non-erythrocytic 1 OS=Homo sapiens GN=SPTAN1 PE=1 SV=3
# 7   sp|P05787|K2C8_HUMAN Keratin; type II cytoskeletal 8 OS=Homo sapiens GN=KRT8 PE=1 SV=7
# 8   sp|P20700|LMNB1_HUMAN Lamin-B1 OS=Homo sapiens GN=LMNB1 PE=1 SV=2
# 9   sp|Q01082|SPTB2_HUMAN Spectrin beta chain; non-erythrocytic 1 OS=Homo sapiens GN=SPTBN1 PE=1 SV=2
# 10  sp|P68133|ACTS_HUMAN Actin; alpha skeletal muscle OS=Homo sapiens GN=ACTA1 PE=1 SV=1
# 11  sp|P04264|K2C1_HUMAN Keratin; type II cytoskeletal 1 OS=Homo sapiens GN=KRT1 PE=1 SV=6
# ...
