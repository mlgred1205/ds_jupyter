# %%
import pandas as pd

# %%
df = pd.read_csv("../data/test_scounts.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f6658ad8091e> in <module>()
#       1 df = pd.read_csv("../data/test_scounts.csv")
# ----> 2 head(df)
#
# NameError: name 'head' is not defined

# %%
df
# Out:
#                                            Description  03292017_UnX_IP2_  \
# 0    sp|P35580|MYH10_HUMAN Myosin-10 OS=Homo sapien...                354
# 1    sp|P35579|MYH9_HUMAN Myosin-9 OS=Homo sapiens ...                426
# 2    sp|P08670|VIME_HUMAN Vimentin OS=Homo sapiens ...                248
# 3    sp|O43707|ACTN4_HUMAN Alpha-actinin-4 OS=Homo ...                161
# 4    sp|P63261|ACTG_HUMAN Actin; cytoplasmic 2 OS=H...                848
# 5    sp|Q13813|SPTN1_HUMAN Spectrin alpha chain; no...                181
# 6    sp|P05787|K2C8_HUMAN Keratin; type II cytoskel...                111
# 7    sp|P20700|LMNB1_HUMAN Lamin-B1 OS=Homo sapiens...                 35
# 8    sp|Q01082|SPTB2_HUMAN Spectrin beta chain; non...                131
# 9    sp|P68133|ACTS_HUMAN Actin; alpha skeletal mus...                470
# 10   sp|P04264|K2C1_HUMAN Keratin; type II cytoskel...                 91
# 11   sp|O94832|MYO1D_HUMAN Unconventional myosin-Id...                 41
# ...
